# %%
#!/usr/bin/python
import turtle

turtle.home()
turtle.clear()
turtle.begin_fill()
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.end_fill()
turtle.forward(20)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.begin_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.left(90)
turtle.forward(20)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.backward(20)
turtle.left(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(20)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.begin_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.left(90)
turtle.forward(20)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
#
turtle.forward(80)
turtle.left(90)
turtle.forward(20)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.begin_fill()
turtle.left(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
#
turtle.forward(70)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.begin_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.left(90)
turtle.forward(20)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.left(90)
turtle.forward(10)
turtle.right(90)
#
turtle.forward(80)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.begin_fill()
turtle.left(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
#
turtle.forward(70)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.begin_fill()
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.left(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.left(90)
turtle.forward(10)
turtle.right(90)
#
turtle.forward(80)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.begin_fill()
turtle.left(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
#
turtle.forward(70)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.begin_fill()
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.left(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.left(90)
turtle.forward(10)
turtle.right(90)
#
turtle.forward(80)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.begin_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.begin_fill()
turtle.left(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(20)
turtle.right(90)
turtle.forward(10)
turtle.end_fill()
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.right(90)
turtle.forward(10)
turtle.backward(10)
turtle.begin_fill()
turtle.backward(10)
turtle.right(90)
turtle.forward(10)
turtle.left(90)
turtle.forward(10)
turtle.end_fill()
